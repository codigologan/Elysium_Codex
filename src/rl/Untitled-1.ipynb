# %% [markdown]
# Elysium_Codex/
# ├─ notebooks/
# ├─ src/
# │  ├─ __init__.py
# │  ├─ utils.py
# │  ├─ data.py
# │  ├─ model.py
# │  └─ train.py
# ├─ scripts/
# │  ├─ train_mlp.ps1
# │  └─ tensorboard.ps1
# ├─ configs/
# │  └─ mlp_default.json
# ├─ runs/            (ignorado pelo git)
# ├─ models/          (ignorado pelo git)
# ├─ requirements-ml.txt
# └─ README.md
#
#
# .\.venv312\Scripts\Activate.ps1
